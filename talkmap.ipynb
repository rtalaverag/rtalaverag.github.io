# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: getorg in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (0.3.1)
# Collecting PyYAML (from python-frontmatter)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: geopy in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from getorg) (2.5.0)
# Requirement already satisfied: retrying in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from geopy->getorg) (2.0)
# Requirement already satisfied: pynacl>=1.4.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pygithub->getorg) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pygithub->getorg) (2.3.0)
# Requirement already satisfied: Deprecated in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pygithub->getorg) (1.2.15)
# Requirement already satisfied: six>=1.7.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from retrying->getorg) (1.16.0)
# Requirement already satisfied: cryptography>=3.4.0 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.1.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from Deprecated->pygithub->getorg) (1.17.0)
# Requirement already satisfied: pycparser in /home/rtala/anaconda3/envs/geo/lib/python3.11/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)
# Downloading python_frontmatter-1.1.0-py3-none-any.whl (9.8 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: PyYAML, python-frontmatter
# Successfully installed PyYAML-6.0.3 python-frontmatter-1.1.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Introducción a ArcGIS Pro<br />Universidad Complutense de Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# Big Data en la planificación del transporte urbano<br />Universidad Nacional del Litoral; Santa Fe de la Veracruz, Argentina Privada Argentina, Delfino Victoria - Santa Fe, Municipio de Veracruz, Veracruz, México
# Introducción al software libre QGIS<br />Facultad de Geografía e Historia, Universidad Complutense de Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# Análisis ráster con QGIS<br />Faculty of Geography and History, Complutense University of Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# Improving pedestrian accessibility to public space through space syntax analysis<br />Pontífica Universidad Católica de Chile; Santiago de Chile, Chile Santiago, Provincia de Santiago, Región Metropolitana de Santiago, 8320000, Chile
# Evaluación del efecto de la pandemia de COVID-19 en el uso del transporte público en la ciudad de Santa Fe de la Vera Cruz, Argentina<br />Universidad de Castilla la Mancha; Cáceres, Spain Cáceres, Extremadura, España
# Who uses Madrid's parks and when?: estimates from mobile phone data usage<br />University of Coimbra; Coimbra, Portugal Coimbra, Portugal
# Introducción al software libre QGIS<br />Faculty of Geography and History, Complutense University of Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# Light rail and planning. Innovations in Andalusian metropolitan areas<br />Liverpool University; Liverpool, United Kingdom Liverpool, Liverpool City Region, England, United Kingdom
# Spatial configuration analysis to improve the accessibility to light-rail stations<br />Universidade Nova de Lisboa; Lisbon, Portugal Lisboa, Portugal
# Integración QGIS – Inkscape para cartografía<br />Faculty of Geography and History, Complutense University of Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# Parques como espacios de mezcla socioeconómica: Análisis de Madrid a partir datos de telefonía móvil.<br />Universidad de Extremadura; Cáceres, España Cáceres, Extremadura, España
# Análisis de patrones de movilidad turística en Madrid mediante datos de telefonía móvil.<br />Universidad de las Islas Baleares; Palma de Mallorca, España Palma, Illes Balears, España
# Big Data geolocalizado<br />Universidad Nacional del Litoral; Santa Fe de la Veracruz, Argentina Privada Argentina, Delfino Victoria - Santa Fe, Municipio de Veracruz, Veracruz, México
# La contribución de las Smart Cities a los ODS<br />Facultad de Ciencias Químicas, Universidad Complutense de Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# A framework to assess the innovation originated by the light rail in the Andalusian metropolitan areas<br />Madrid; Madrid, Spain Madrid, Comunidad de Madrid, España
# Pedestrian accessibility to public space: the implication of the urban form in the city of Granada<br />Porto University; Porto, Portugal Porto, Portugal
# Pedestrian mobility: definition, evaluation and prospects<br />University College Dublin; Dublin, Ireland Dublin, County Dublin, Leinster, Éire / Ireland
# Walking distance to transit: making public transport more human and successful<br />Facultad de Arquitectura, Universidad de Granada; Granada, Spain Granada, Comarca de la Vega de Granada, Granada, Andalucía, España
# Evaluación del nivel de servicio peatonal en Madrid a partir de datos de sensores fijos<br />Universidad de Zaragoza; Zaragoza, Spain Zaragoza, Aragón, España

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
